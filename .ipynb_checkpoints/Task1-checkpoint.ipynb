# %%
import pandas as pd
import numpy as np
import random
import math
import seaborn as sns 
from math import sqrt
import matplotlib.pyplot as plt
import plotly.express as px
from ts2vg import NaturalVG

# %%
#going with acclerometer on head

#subject1
s1_run = pd.read_csv('data/subject1/acc_running_csv/acc_running_chest.csv')
s1_walk = pd.read_csv('data/subject1/acc_walking_csv/acc_walking_chest.csv')
s1_climbUp = pd.read_csv('data/subject1/acc_climbingup_csv/acc_climbingup_chest.csv')
s1_climbDown = pd.read_csv('data/subject1/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject2
s2_run = pd.read_csv('data/subject2/acc_running_csv/acc_running_chest.csv')
s2_walk = pd.read_csv('data/subject2/acc_walking_csv/acc_walking_chest.csv')
s2_climbUp = pd.read_csv('data/subject2/acc_climbingup_csv/acc_climbingup_chest.csv')
s2_climbDown = pd.read_csv('data/subject2/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject3
s3_run = pd.read_csv('data/subject3/acc_running_csv/acc_running_chest.csv')
s3_walk = pd.read_csv('data/subject3/acc_walking_csv/acc_walking_chest.csv')
s3_climbUp = pd.read_csv('data/subject3/acc_climbingup_csv/acc_climbingup_chest.csv')
s3_climbDown = pd.read_csv('data/subject3/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject4
s4_run = pd.read_csv('data/subject4/acc_running_csv/acc_running_chest.csv')
s4_walk = pd.read_csv('data/subject4/acc_walking_csv/acc_walking_2_chest.csv')
s4_climbUp = pd.read_csv('data/subject4/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_chest.csv')
s4_climbDown = pd.read_csv('data/subject4/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_chest.csv')

#subject5
s5_run = pd.read_csv('data/subject5/acc_running_csv/acc_running_chest.csv')
s5_walk = pd.read_csv('data/subject5/acc_walking_csv/acc_walking_chest.csv')
s5_climbUp = pd.read_csv('data/subject5/acc_climbingup_csv/acc_climbingup_chest.csv')
s5_climbDown = pd.read_csv('data/subject5/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject6
s6_run = pd.read_csv('data/subject6/acc_running_csv/acc_running_chest.csv')
s6_walk = pd.read_csv('data/subject6/acc_walking_csv/acc_walking_chest.csv')
s6_climbUp = pd.read_csv('data/subject6/acc_climbingup_csv/acc_climbingup_chest.csv')
s6_climbDown = pd.read_csv('data/subject6/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject7
s7_run = pd.read_csv('data/subject7/acc_running_csv/acc_running_chest.csv')
s7_walk = pd.read_csv('data/subject7/acc_walking_csv/acc_walking_chest.csv')
s7_climbUp = pd.read_csv('data/subject7/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_chest.csv')
s7_climbDown = pd.read_csv('data/subject7/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_chest.csv')

#subject8
s8_run = pd.read_csv('data/subject8/acc_running_csv/acc_running_chest.csv')
s8_walk = pd.read_csv('data/subject8/acc_walking_csv/acc_walking_chest.csv')
s8_climbUp = pd.read_csv('data/subject8/acc_climbingup_csv/acc_climbingup_chest.csv')
s8_climbDown = pd.read_csv('data/subject8/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject9
s9_run = pd.read_csv('data/subject9/acc_running_csv/acc_running_chest.csv')
s9_walk = pd.read_csv('data/subject9/acc_walking_csv/acc_walking_chest.csv')
s9_climbUp = pd.read_csv('data/subject9/acc_climbingup_csv/acc_climbingup_chest.csv')
s9_climbDown = pd.read_csv('data/subject9/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject10
s10_run = pd.read_csv('data/subject10/acc_running_csv/acc_running_chest.csv')
s10_walk = pd.read_csv('data/subject10/acc_walking_csv/acc_walking_chest.csv')
s10_climbUp = pd.read_csv('data/subject10/acc_climbingup_csv/acc_climbingup_chest.csv')
s10_climbDown = pd.read_csv('data/subject10/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject11
s11_run = pd.read_csv('data/subject11/acc_running_csv/acc_running_chest.csv')
s11_walk = pd.read_csv('data/subject11/acc_walking_csv/acc_walking_chest.csv')
s11_climbUp = pd.read_csv('data/subject11/acc_climbingup_csv/acc_climbingup_chest.csv')
s11_climbDown = pd.read_csv('data/subject11/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject12
s12_run = pd.read_csv('data/subject12/acc_running_csv/acc_running_chest.csv')
s12_walk = pd.read_csv('data/subject12/acc_walking_csv/acc_walking_chest.csv')
s12_climbUp = pd.read_csv('data/subject12/acc_climbingup_csv/acc_climbingup_chest.csv')
s12_climbDown = pd.read_csv('data/subject12/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject13
s13_run = pd.read_csv('data/subject13/acc_running_csv/acc_running_chest.csv')
s13_walk = pd.read_csv('data/subject13/acc_walking_csv/acc_walking_2_chest.csv')
s13_climbUp = pd.read_csv('data/subject13/acc_climbingup_csv/acc_climbingup_chest.csv')
s13_climbDown = pd.read_csv('data/subject13/acc_climbingdown_csv/acc_climbingdown_chest.csv')

#subject14
s14_run = pd.read_csv('data/subject14/acc_running_csv/acc_running_chest.csv')
s14_walk = pd.read_csv('data/subject14/acc_walking_csv/acc_walking_chest.csv')
s14_climbUp = pd.read_csv('data/subject14/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_chest.csv')
s14_climbDown = pd.read_csv('data/subject14/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_chest.csv')

#subject15
s15_run = pd.read_csv('data/subject15/acc_running_csv/acc_running_chest.csv')
s15_walk = pd.read_csv('data/subject15/acc_walking_csv/acc_walking_chest.csv')
s15_climbUp = pd.read_csv('data/subject15/acc_climbingup_csv/acc_climbingup_chest.csv')
s15_climbDown = pd.read_csv('data/subject15/acc_climbingdown_csv/acc_climbingdown_chest.csv')

# %%
def calculate_resultant(df):
    df = df['attr_x']**2+df['attr_y']**2+df['attr_z']**2
    df['res']=df**0.5
    return df

# %%
dataset_list = [s1_run, s1_walk, s1_climbUp, s1_climbDown, s2_run, s2_walk, s2_climbUp, s2_climbDown, s3_run, 
                s3_walk, s3_climbUp, s3_climbDown, s4_run, s4_walk, s4_climbUp, s4_climbDown, 
                s5_run, s5_walk, s5_climbUp, s5_climbDown, s6_run, s6_walk, s6_climbUp, s6_climbDown, 
                s7_run, s7_walk, s7_climbUp, s7_climbDown, s8_run, s8_walk, s8_climbUp, s8_climbDown, 
                s9_run, s9_walk, s9_climbUp, s9_climbDown, s10_run, s10_walk, s10_climbUp, s10_climbDown, 
                s11_run, s11_walk, s11_climbUp, s11_climbDown, s12_run, s12_walk, s12_climbUp, 
                s12_climbDown, s13_run, s13_walk, s13_climbUp, s13_climbDown, s14_run, s14_walk, 
                s14_climbUp, s14_climbDown, s15_run, s15_walk, s15_climbUp, s15_climbDown]

for dataset in dataset_list:
    dataset['res']=calculate_resultant(dataset)

# %%
sns.lineplot(x=range(1, len(s1_run['res'][1000:2048])+1), y=s1_walk['res'][1000:2048])
# Out:
# <AxesSubplot:ylabel='res'>
