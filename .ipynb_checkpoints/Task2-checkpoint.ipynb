# %%
import pandas as pd
import numpy as np
import random
import math
import seaborn as sns 
from math import sqrt
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#going with acclerometer on head

#subject1
s1_run = pd.read_csv('data/subject1/acc_running_csv/acc_running_head.csv')
s1_walk = pd.read_csv('data/subject1/acc_walking_csv/acc_walking_head.csv')
s1_climbUp = pd.read_csv('data/subject1/acc_climbingup_csv/acc_climbingup_head.csv')
s1_climbDown = pd.read_csv('data/subject1/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject2
s2_run = pd.read_csv('data/subject2/acc_running_csv/acc_running_head.csv')
s2_walk = pd.read_csv('data/subject2/acc_walking_csv/acc_walking_head.csv')
s2_climbUp = pd.read_csv('data/subject2/acc_climbingup_csv/acc_climbingup_head.csv')
s2_climbDown = pd.read_csv('data/subject2/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject3
s3_run = pd.read_csv('data/subject3/acc_running_csv/acc_running_head.csv')
s3_walk = pd.read_csv('data/subject3/acc_walking_csv/acc_walking_head.csv')
s3_climbUp = pd.read_csv('data/subject3/acc_climbingup_csv/acc_climbingup_head.csv')
s3_climbDown = pd.read_csv('data/subject3/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject4
s4_run = pd.read_csv('data/subject4/acc_running_csv/acc_running_head.csv')
s4_walk = pd.read_csv('data/subject4/acc_walking_csv/acc_walking_2_head.csv')
s4_climbUp = pd.read_csv('data/subject4/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_head.csv')
s4_climbDown = pd.read_csv('data/subject4/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_head.csv')

#subject5
s5_run = pd.read_csv('data/subject5/acc_running_csv/acc_running_head.csv')
s5_walk = pd.read_csv('data/subject5/acc_walking_csv/acc_walking_head.csv')
s5_climbUp = pd.read_csv('data/subject5/acc_climbingup_csv/acc_climbingup_head.csv')
s5_climbDown = pd.read_csv('data/subject5/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject6
s6_run = pd.read_csv('data/subject6/acc_running_csv/acc_running_head.csv')
s6_walk = pd.read_csv('data/subject6/acc_walking_csv/acc_walking_head.csv')
s6_climbUp = pd.read_csv('data/subject6/acc_climbingup_csv/acc_climbingup_head.csv')
s6_climbDown = pd.read_csv('data/subject6/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject7
s7_run = pd.read_csv('data/subject7/acc_running_csv/acc_running_head.csv')
s7_walk = pd.read_csv('data/subject7/acc_walking_csv/acc_walking_head.csv')
s7_climbUp = pd.read_csv('data/subject7/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_head.csv')
s7_climbDown = pd.read_csv('data/subject7/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_head.csv')

#subject8
s8_run = pd.read_csv('data/subject8/acc_running_csv/acc_running_head.csv')
s8_walk = pd.read_csv('data/subject8/acc_walking_csv/acc_walking_head.csv')
s8_climbUp = pd.read_csv('data/subject8/acc_climbingup_csv/acc_climbingup_head.csv')
s8_climbDown = pd.read_csv('data/subject8/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject9
s9_run = pd.read_csv('data/subject9/acc_running_csv/acc_running_head.csv')
s9_walk = pd.read_csv('data/subject9/acc_walking_csv/acc_walking_head.csv')
s9_climbUp = pd.read_csv('data/subject9/acc_climbingup_csv/acc_climbingup_head.csv')
s9_climbDown = pd.read_csv('data/subject9/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject10
s10_run = pd.read_csv('data/subject10/acc_running_csv/acc_running_head.csv')
s10_walk = pd.read_csv('data/subject10/acc_walking_csv/acc_walking_head.csv')
s10_climbUp = pd.read_csv('data/subject10/acc_climbingup_csv/acc_climbingup_head.csv')
s10_climbDown = pd.read_csv('data/subject10/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject11
s11_run = pd.read_csv('data/subject11/acc_running_csv/acc_running_head.csv')
s11_walk = pd.read_csv('data/subject11/acc_walking_csv/acc_walking_head.csv')
s11_climbUp = pd.read_csv('data/subject11/acc_climbingup_csv/acc_climbingup_head.csv')
s11_climbDown = pd.read_csv('data/subject11/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject12
s12_run = pd.read_csv('data/subject12/acc_running_csv/acc_running_head.csv')
s12_walk = pd.read_csv('data/subject12/acc_walking_csv/acc_walking_head.csv')
s12_climbUp = pd.read_csv('data/subject12/acc_climbingup_csv/acc_climbingup_head.csv')
s12_climbDown = pd.read_csv('data/subject12/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject13
s13_run = pd.read_csv('data/subject13/acc_running_csv/acc_running_head.csv')
s13_walk = pd.read_csv('data/subject13/acc_walking_csv/acc_walking_2_head.csv')
s13_climbUp = pd.read_csv('data/subject13/acc_climbingup_csv/acc_climbingup_head.csv')
s13_climbDown = pd.read_csv('data/subject13/acc_climbingdown_csv/acc_climbingdown_head.csv')

#subject14
s14_run = pd.read_csv('data/subject14/acc_running_csv/acc_running_head.csv')
s14_walk = pd.read_csv('data/subject14/acc_walking_csv/acc_walking_head.csv')
s14_climbUp = pd.read_csv('data/subject14/acc_climbingup_csv/acc_climbingup_1_csv/acc_climbingup_head.csv')
s14_climbDown = pd.read_csv('data/subject14/acc_climbingdown_csv/acc_climbingdown_1_csv/acc_climbingdown_head.csv')

#subject15
s15_run = pd.read_csv('data/subject15/acc_running_csv/acc_running_head.csv')
s15_walk = pd.read_csv('data/subject15/acc_walking_csv/acc_walking_head.csv')
s15_climbUp = pd.read_csv('data/subject15/acc_climbingup_csv/acc_climbingup_head.csv')
s15_climbDown = pd.read_csv('data/subject15/acc_climbingdown_csv/acc_climbingdown_head.csv')

# %%
def calculate_resultant(df):
    df = df['attr_x']**2+df['attr_y']**2+df['attr_z']**2
    df['res']=df**0.5
    return df

# %%
s1_run['res']=calculate_resultant(s1_run)

# %%
s1_walk['res']=calculate_resultant(s1_walk)

# %%
sns.set(rc={'figure.figsize':(18,8)})
sns.lineplot(x=range(1,len(s1_run['res'][1000:4096])+1), y=s1_run['res'][1000:4096])
# Out:
# <AxesSubplot:ylabel='res'>

# %%
dataset_list = [s1_climbUp, s1_climbDown, s2_run, s2_walk, s2_climbUp, s2_climbDown, s3_run, 
                s3_walk, s3_climbUp, s3_climbDown, s4_run, s4_walk, s4_climbUp, s4_climbDown, 
                s5_run, s5_walk, s5_climbUp, s5_climbDown, s6_run, s6_walk, s6_climbUp, s6_climbDown, 
                s7_run, s7_walk, s7_climbUp, s7_climbDown, s8_run, s8_walk, s8_climbUp, s8_climbDown, 
                s9_run, s9_walk, s9_climbUp, s9_climbDown, s10_run, s10_walk, s10_climbUp, s10_climbDown, 
                s11_run, s11_walk, s11_climbUp, s11_climbDown, s12_run, s12_walk, s12_climbUp, 
                s12_climbDown, s13_run, s13_walk, s13_climbUp, s13_climbDown, s14_run, s14_walk, 
                s14_climbUp, s14_climbDown, s15_run, s15_walk, s15_climbUp, s15_climbDown]

for dataset in dataset_list:
    dataset['res']=calculate_resultant(dataset)

# %%
##Github code to calculate entropy, complexity, ordinal patterns etc.
def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

def weighted_ordinal_patterns(ts, embdim, embdelay):
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    xm = np.mean(partition, axis=1)
    weight = np.mean((partition - xm[:, None])**2, axis=1)
    permutation = np.argsort(partition)
    idx = _hash(permutation)
    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = sum(weight[i == idx])

    return list(counts[counts != 0])

# %%
j=0
permutation_entropy=[]
complexity_measure=[]
activity=[]
embeded_dimension = []
d = []
subject = []
embeded_dimension_list = [3,4,5,6]
delay = 1
for ed in embeded_dimension_list:
    for i in range(1,50):
      op_run=ordinal_patterns(s1_run['res'][j:(j+4096)],ed,delay)
      op_walk=ordinal_patterns(s1_walk['res'][j:(j+4096)],ed,delay)

      subject.append(1)
      embeded_dimension.append(ed)
      d.append(delay)
      permutation_entropy.append(p_entropy(op_run))
      complexity_measure.append(complexity(op_run))
      activity.append("running")
    
      subject.append(1)
      embeded_dimension.append(ed)
      d.append(delay)
      permutation_entropy.append(p_entropy(op_walk))
      complexity_measure.append(complexity(op_walk))
      activity.append("walking")


      j=j+129


result=pd.DataFrame({'Subject':subject, 'Dimension':embeded_dimension, 'Delay':d, 'permutation_entropy':permutation_entropy, 'complexity': complexity_measure, 'activity': activity})

# %%
result
# Out:
#      Subject  Dimension  Delay  permutation_entropy  complexity activity
# 0          1          3      1             0.808752    0.139451  running
# 1          1          3      1             0.877399    0.103483  walking
# 2          1          3      1             0.800528    0.143753  running
# 3          1          3      1             0.875311    0.104879  walking
# 4          1          3      1             0.798969    0.144388  running
# ..       ...        ...    ...                  ...         ...      ...
# 387        1          6      1             0.808550    0.261512  walking
# 388        1          6      1             0.646731    0.285435  running
# 389        1          6      1             0.808419    0.261451  walking
# 390        1          6      1             0.645597    0.287554  running
# 391        1          6      1             0.809288    0.259323  walking
#
# [392 rows x 6 columns]

# %%
for ed in embeded_dimension_list:
    print("*************************************************************************************************************************")
    print('Subject : '+str(1))
    print('Dimension : '+str(ed))
    print('Delay : '+str(1))
    df_plotter = result[result.Dimension==ed]
    sns.scatterplot(data=df_plotter, x="permutation_entropy", y="complexity", hue="activity")
    plt.show()
# Out:
# *************************************************************************************************************************
# Subject : 1
# Dimension : 3
# Delay : 1
# *************************************************************************************************************************
# Subject : 1
# Dimension : 4
# Delay : 1
# *************************************************************************************************************************
# Subject : 1
# Dimension : 5
# Delay : 1
# *************************************************************************************************************************
# Subject : 1
# Dimension : 6
# Delay : 1
